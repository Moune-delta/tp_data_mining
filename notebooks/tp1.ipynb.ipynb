# %%
import pandas as pd
import numpy as np

print("Environnement configuré avec succès !")
print("Version de Pandas :", pd.__version__)
# Out:
# Environnement configuré avec succès !
# Version de Pandas : 2.3.3

# %%
import pandas as pd

path = "C:/Users/ADMIN/Downloads/student+performance/student/student-mat.csv"

df = pd.read_csv(path, sep=';')

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
import pandas as pd

path = "C:/Users/ADMIN/Downloads/student+performance/student/student-mat.csv"

df = pd.read_csv(path, sep=';')

print("Aperçu des données:")
display(df.head())

print("\nInformations sur le dataset:")
df.info()
# Out:
# Aperçu des données:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
# Informations sur le dataset:
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
import pandas as pd

url = "https://jsonplaceholder.typicode.com/posts"

df_json = pd.read_json(url)

df_json.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
import pandas as pd

url = "https://github.com/pandas-dev/pandas/raw/main/doc/data/titanic.xlsx"

df_excel = pd.read_excel(url)

df_excel.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 import pandas as pd
#       3 url = "https://github.com/pandas-dev/pandas/raw/main/doc/data/titanic.xlsx"
# ----> 5 df_excel = pd.read_excel(url)
#       7 df_excel.head()
#
# File ~\anaconda3\envs\tp_data_mining\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv"

df_excel = pd.read_csv(url)

df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd 
import sqlite3

# %%
df = pd.read_csv("C:/Users/ADMIN/Downloads/student+performance/student/student-mat.csv", sep=";")

# %%
conn = sqlite3.connect("students.db")

# %%
df.to_sql("etudiants", conn, if_exists="replace", index=False)
# Out:
# 395

# %%
G3 > 15
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 G3 > 15
#
# NameError: name 'G3' is not defined

# %%
query = "SELECT * FROM etudiants WHERE G3 > 15"

# %%
df_sql = pd.read_sql_query(query, conn)

df_sql.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   M   15       U     LE3       A     3     2  services     other
# 1     GP   M   15       U     GT3       A     2     2     other     other
# 2     GP   M   16       U     LE3       T     4     2   teacher     other
# 3     GP   M   15       U     GT3       T     4     4  services  services
# 4     GP   M   15       R     GT3       T     4     3   teacher   at_home
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        2      2     1     1      1        0  16  18  19
# 1  ...      4        5      2     1     1      3        0  14  16  16
# 2  ...      4        5      1     1     3      5        2  15  15  16
# 3  ...      4        3      1     1     1      5        0  17  16  17
# 4  ...      4        5      2     1     1      5        0  17  16  16
#
# [5 rows x 33 columns]

# %%
import requests
import pandas as pd

url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)

data = response.json()

df_api = pd.DataFrame(data)

df_api.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com"

page = requests.get(url)

soup = BeautifulSoup(page.text, "html.parser")

titles = soup.find_all("h1")

for t in titles:
    print(t.text)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\anaconda3\envs\tp_data_mining\lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\anaconda3\envs\tp_data_mining\lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\anaconda3\envs\tp_data_mining\lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "http://example.com"

page = requests.get(url, verify=False)

soup = BeautifulSoup(page.text, "html.parser")

titles = soup.find_all("h1")

for t in titles:
    print(t.text)
# Out:
# Example Domain

# %%
final_df = pd.concat([df, df_sql, df_api], ignore_index=True)

final_df.head()
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  18.0       U     GT3       A   4.0   4.0  at_home   teacher
# 1     GP   F  17.0       U     GT3       T   1.0   1.0  at_home     other
# 2     GP   F  15.0       U     LE3       T   1.0   1.0  at_home     other
# 3     GP   F  15.0       U     GT3       T   4.0   2.0   health  services
# 4     GP   F  16.0       U     GT3       T   3.0   3.0    other     other
#
#    ... Walc health  absences    G1    G2    G3 userId  id title body
# 0  ...  1.0    3.0       6.0   5.0   6.0   6.0    NaN NaN   NaN  NaN
# 1  ...  1.0    3.0       4.0   5.0   5.0   6.0    NaN NaN   NaN  NaN
# 2  ...  3.0    3.0      10.0   7.0   8.0  10.0    NaN NaN   NaN  NaN
# 3  ...  1.0    5.0       2.0  15.0  14.0  15.0    NaN NaN   NaN  NaN
# 4  ...  2.0    5.0       4.0   6.0  10.0  10.0    NaN NaN   NaN  NaN
#
# [5 rows x 37 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      435 non-null    object
#  1   sex         435 non-null    object
#  2   age         435 non-null    float64
#  3   address     435 non-null    object
#  4   famsize     435 non-null    object
#  5   Pstatus     435 non-null    object
#  6   Medu        435 non-null    float64
#  7   Fedu        435 non-null    float64
#  8   Mjob        435 non-null    object
#  9   Fjob        435 non-null    object
#  10  reason      435 non-null    object
#  11  guardian    435 non-null    object
#  12  traveltime  435 non-null    float64
#  13  studytime   435 non-null    float64
#  14  failures    435 non-null    float64
#  15  schoolsup   435 non-null    object
#  16  famsup      435 non-null    object
#  17  paid        435 non-null    object
#  18  activities  435 non-null    object
# ...

# %%
final_df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  435.000000  435.000000  435.000000  435.000000  435.000000  435.000000
# mean    16.668966    2.802299    2.547126    1.432184    2.050575    0.305747
# std      1.273924    1.089326    1.094376    0.683494    0.854491    0.715747
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    3.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    4.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  435.000000  435.000000  435.000000  435.000000  435.000000  435.000000
# mean     3.956322    3.245977    3.094253    1.462069    2.255172    3.531034
# ...
